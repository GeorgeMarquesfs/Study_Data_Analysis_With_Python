# %%
# !mkdir -p "/content/drive/MyDrive/Data_Science/vacina-covid"

# %%
# !wget -P "/content/drive/MyDrive/Data_Science/vacina-covid" https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DPB/part-00004-d1137fe2-014a-4a03-90ca-12cbec8fae79.c000.csv
# Out:
# --2023-06-05 16:53:07--  https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DPB/part-00004-d1137fe2-014a-4a03-90ca-12cbec8fae79.c000.csv
# Resolving s3.sa-east-1.amazonaws.com (s3.sa-east-1.amazonaws.com)... 52.95.165.58
# Connecting to s3.sa-east-1.amazonaws.com (s3.sa-east-1.amazonaws.com)|52.95.165.58|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 999118252 (953M) [text/csv]
# Saving to: ‘/content/drive/MyDrive/Data_Science/vacina-covid/part-00004-d1137fe2-014a-4a03-90ca-12cbec8fae79.c000.csv’
#
# part-00004-d1137fe2 100%[===================>] 952.83M  21.2MB/s    in 48s
#
# 2023-06-05 16:53:55 (19.9 MB/s) - ‘/content/drive/MyDrive/Data_Science/vacina-covid/part-00004-d1137fe2-014a-4a03-90ca-12cbec8fae79.c000.csv’ saved [999118252/999118252]

# %%
import pandas as pd
import seaborn as sns

# %%
sns.set()

# %%
vacina_PB = pd.read_csv('/content/drive/MyDrive/Data_Science/vacina-covid/part-00004-d1137fe2-014a-4a03-90ca-12cbec8fae79.c000.csv', sep=';')
# Out:
# <ipython-input-4-11267e4f2ffb>:1: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   vacina_PB = pd.read_csv('/content/drive/MyDrive/Data_Science/vacina-covid/part-00004-d1137fe2-014a-4a03-90ca-12cbec8fae79.c000.csv', sep=';')

# %%
vacina_PB.head()
# Out:
#                                  document_id  \
# 0  c801d057-4cb0-47cb-a154-33d1e5368cfd-i0b0
# 1  97493f88-7c04-494c-846e-688e4436d093-i0b0
# 2  c80321b5-109f-4252-a74d-2ab87a17ab6c-i0b0
# 3  974c0ebe-fd1e-429d-9d8c-66c3aa5c2b3a-i0b0
# 4  c80513ae-eae7-42fe-a05c-4897c8ea0594-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  4e1e58c70e0d1040f93218ee37f243dbc1dbe5669fa71e...            12.0
# 1  f455f21ee53619bee6b9b6074cce6259a7e09ba807637c...            17.0
# 2  0e3a0765b7cb36aa4687e0b674b022db0acf469d6685bb...            14.0
# 3  fc226c768007b62cf813e5a73ede954d5dd50c15f92564...            71.0
# 4  7228e29fd3202bd9e1dea313532c886ac74032801a177c...            34.0
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              2009-11-19                          M                      4.0
# 1              2004-09-30                          M                      5.0
# ...

# %%
vacina_PB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2039569 entries, 0 to 2039568
# Data columns (total 32 columns):
#  #   Column                                    Dtype
# ---  ------                                    -----
#  0   document_id                               object
#  1   paciente_id                               object
#  2   paciente_idade                            float64
#  3   paciente_dataNascimento                   object
#  4   paciente_enumSexoBiologico                object
#  5   paciente_racaCor_codigo                   float64
#  6   paciente_racaCor_valor                    object
#  7   paciente_endereco_coIbgeMunicipio         object
#  8   paciente_endereco_coPais                  object
#  9   paciente_endereco_nmMunicipio             object
#  10  paciente_endereco_nmPais                  object
#  11  paciente_endereco_uf                      object
#  12  paciente_endereco_cep                     object
# ...

# %%
vacina_PB.paciente_racaCor_valor.value_counts(normalize=True).plot(kind='bar')
# Out:
# <Axes: >

# %%
vacina_PB.vacina_fabricante_nome.value_counts(normalize=True).plot(kind='bar')
# Out:
# <Axes: >

# %%
vacina_PB.groupby(['paciente_idade','vacina_grupoAtendimento_nome']).count()
# Out:
#                                                                document_id  \
# paciente_idade vacina_grupoAtendimento_nome
# -47.0          Pessoas de 18 a 64 anos                                   1
# -46.0          Outros                                                    1
# -43.0          Pessoas de 18 a 64 anos                                   1
# -35.0          Pessoas de 18 a 64 anos                                   1
# -8.0           Pessoas de 18 a 64 anos                                   1
# ...                                                                    ...
#  121.0         Sem registro no modelo de informação de origem            1
#                Técnico de Enfermagem                                     2
#  122.0         Faixa Etária                                              1
#                Pessoas de 18 a 64 anos                                   2
#  123.0         Faixa Etária                                              1
#
# ...

# %%
vacina_PB[vacina_PB.paciente_idade == 0]
# Out:
#                                        document_id  \
# 925      a3957c34-f3fe-4767-a935-8652a2965dbf-i0b0
# 2982     ec814f1d-03cd-4db3-824b-19cf4138d2fb-i0b0
# 3800     f7ddacfb-c3a5-4433-9c68-3355b2a8c22d-i0b0
# 7456     55a7d6fb-ad67-48e3-9cd6-8adc110158d8-i0b0
# 9457     1b00dd53-cdd0-4657-b3e9-bd687864c924-i0b0
# ...                                            ...
# 2032644  8b037fb1-3cd9-4993-8236-081fa10aed7e-i0b0
# 2034665  49f6cc42-17d0-43b0-8253-4670ad8d32d4-i0b0
# 2036334  8c37a45b-8a31-43d4-a8df-ea1316243ccd-i0b0
# 2036818  062ffe97-930a-4551-b27f-c400c9ba7b11-i0b0
# 2039203  4272980d-d078-421a-8fbb-548161e00467-i0b0
#
#                                                paciente_id  paciente_idade  \
# 925      96a670723a5f2631ea074b7826d20592ef6b7d06925764...             0.0
# 2982     440f9e87016cd7acba51bd8a324ef87da944b70b017c4e...             0.0
# 3800     ab2a727688db36501485db8ae335a88452f665b2827d40...             0.0
# ...

# %%
pd.to_datetime(vacina_PB.vacina_dataAplicacao)
# Out:
# 0         2022-02-07
# 1         2021-10-08
# 2         2022-04-11
# 3         2021-04-19
# 4         2021-08-01
#              ...
# 2039564   2021-08-10
# 2039565   2022-01-10
# 2039566   2021-12-14
# 2039567   2021-11-17
# 2039568   2021-04-07
# Name: vacina_dataAplicacao, Length: 2039569, dtype: datetime64[ns]
